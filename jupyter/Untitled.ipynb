# %%
# IMPORTS


import nbtlib

# %%
# LOAD FILES

nbt_file = nbtlib.load('../data/playerdata/83a71a90-51e1-4eb9-906d-669b3650c47d.dat')

# %%
print(nbt_file)
# Out:
# <File '': Compound({'Brain': Compound({'memories': Compound({})}), 'HurtByTimestamp': Int(0), 'SleepTimer': Short(0), 'Attributes': List[Compound]([Compound({'Base': Double(20.0), 'Name': String('generic.maxHealth')}), Compound({'Base': Double(0.0), 'Name': String('generic.knockbackResistance')}), Compound({'Base': Double(0.10000000149011612), 'Name': String('generic.movementSpeed')}), Compound({'Base': Double(0.0), 'Name': String('generic.armor')}), Compound({'Base': Double(0.0), 'Name': String('generic.armorToughness')}), Compound({'Base': Double(1.0), 'Name': String('generic.attackDamage')}), Compound({'Base': Double(4.0), 'Name': String('generic.attackSpeed')}), Compound({'Base': Double(0.0), 'Name': String('generic.luck')})]), 'Invulnerable': Byte(0), 'FallFlying': Byte(0), 'PortalCooldown': Int(0), 'AbsorptionAmount': Float(0.0), 'abilities': Compound({'invulnerable': Byte(1), 'mayfly': Byte(1), 'instabuild': Byte(1), 'walkSpeed': Float(0.10000000149011612), 'mayBuild': Byte(1)
# ...
